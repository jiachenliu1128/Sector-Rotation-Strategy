# %% [markdown]
# # Build Models

# %% [markdown]
# ## Set current working directory to repo root

# %%
import os
from pathlib import Path
import ipynbname

# Get parent directory (repo root)
notebook_path = Path(ipynbname.path())
repo_root = notebook_path.parent.parent
os.chdir(repo_root)
print(f"Notebook path: {notebook_path}")
print(f"Working directory: {os.getcwd()}")
# Out:
# Notebook path: c:\Users\jiach\Repositories\Sector-Rotation-Strategy\notebooks\build_models.ipynb
# Working directory: c:\Users\jiach\Repositories\Sector-Rotation-Strategy

# %% [markdown]
# ## Download & prep data

# %%
# !python src/data_loader.py
# !python src/fred_data_prep.py
# !python src/etf_data_prep.py
# !python src/etf_compute_features.py
# Out:
# [INFO] Starting data loading process...
# [INFO] Configuration loaded.
# [INFO] Downloading ETF data for 10 tickers from 2015-01-01 to 2025-01-01...
# [INFO] Downloading data for XLF...
#
# [*********************100%***********************]  1 of 1 completed
# [INFO] Downloading data for XLK...
#
# [*********************100%***********************]  1 of 1 completed
# [INFO] Downloading data for XLE...
#
# [*********************100%***********************]  1 of 1 completed
# [INFO] Downloading data for XLV...
#
# [*********************100%***********************]  1 of 1 completed
# [INFO] Downloading data for XLI...
#
# [*********************100%***********************]  1 of 1 completed
# [INFO] Downloading data for XLP...
#
# [*********************100%***********************]  1 of 1 completed
# [INFO] Downloading data for XLY...
#
# [*********************100%***********************]  1 of 1 completed
# [INFO] Downloading data for XLB...
#
# [*********************100%***********************]  1 of 1 completed
# [INFO] Downloading data for XLU...
#
# [*********************100%***********************]  1 of 1 completed
# [INFO] Downloading data for SPY...
#
# [*********************100%***********************]  1 of 1 completed
# [INFO] Saved ETF data csv at: data\raw\etf_data.csv
# [INFO] Saved table 'etf_data' to SQLite database at 'data\data.db'
# [INFO] Saved trading calendar data csv at: data\raw\calendar.csv
# [INFO] Saved table 'calendar' to SQLite database at 'data\data.db'
# [INFO] Fetching ETF fundamentals for 10 tickers...
# [INFO] Saved ETF fundamentals csv at: data\raw\etf_fundamentals.csv
# [INFO] Saved table 'etf_fundamentals' to SQLite database at 'data\data.db'
# [INFO] Downloading FRED data for 4 series...
# [INFO] Downloading data for CPIAUCSL...
# [INFO] Downloading data for GDP...
# [INFO] Downloading data for FEDFUNDS...
# [INFO] Downloading data for DGS10...
# [INFO] Saved FRED series CPIAUCSL data csv at: data\raw\fred_CPIAUCSL.csv
# [INFO] Saved table 'fred_CPIAUCSL' to SQLite database at 'data\data.db'
# [INFO] Saved FRED series GDP data csv at: data\raw\fred_GDP.csv
# [INFO] Saved table 'fred_GDP' to SQLite database at 'data\data.db'
# [INFO] Saved FRED series FEDFUNDS data csv at: data\raw\fred_FEDFUNDS.csv
# [INFO] Saved table 'fred_FEDFUNDS' to SQLite database at 'data\data.db'
# [INFO] Saved FRED series DGS10 data csv at: data\raw\fred_DGS10.csv
# [INFO] Saved table 'fred_DGS10' to SQLite database at 'data\data.db'
# [INFO] Loaded 4 FRED tables from SQLite Database at: data/data.db
# [WARNING] Some daily macro series contain NaNs after resampling: ['fred_CPIAUCSL', 'fred_DGS10', 'fred_FEDFUNDS', 'fred_GDP']
# c:\Users\jiach\Repositories\Sector-Rotation-Strategy\src\fred_data_prep.py:136: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   out["CPI_yoy"] = out["fred_CPIAUCSL"].pct_change(365)
# c:\Users\jiach\Repositories\Sector-Rotation-Strategy\src\fred_data_prep.py:142: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   out["GDP_yoy"] = out["fred_GDP"].pct_change(365)
# [INFO] Prepared macro daily DataFrame with shape: (29211, 12)
# [INFO] Saved macro_daily table to SQLite DB at: data\data.db
# [INFO] Saved macro_daily CSV to: data\processed\macro_daily.csv
# [INFO] Loaded daily prices from SQLite Database at: data/data.db (table 'etf_data')
# [INFO] Saved daily prices table to SQLite DB at: data\data.db (table 'prices_daily')
# [INFO] Saved daily prices CSV to: data\processed\prices_daily.csv
# [INFO] Loaded daily prices from SQLite Database at: data\data.db (table 'prices_daily')
# [INFO] Saved features to SQLite DB at: data\data.db (table 'features_daily')
# [INFO] Saved daily features CSV to: data\processed\features_daily.csv

# %% [markdown]
# ## Build modeling tables

# %%
# !python src/build_feature_and_target.py
# Out:
# [WARNING] Dropping 1107 rows with NaNs (in features or targets).
# [INFO] Wrote tables 'X_features' and 'y_targets' to SQLite DB: data\data.db
# [INFO] Saved features at: data\processed\X_features.csv
# [INFO] Saved targets at: data\processed\y_targets.csv

# %% [markdown]
# ## Train & score models

# %% [markdown]
# ### Regression Models

# %%
# !python src/fit_models.py --task regression --model ridge

# %%
# !python src/fit_models.py --task regression --model rf

# %%
# !python src/fit_models.py --task regression --model xgb --use_gpu

# %%
# !python src/fit_models.py --task regression --model lstm --use_gpu

# %%
# !python src/fit_models.py --task regression --model transformer --use_gpu

# %% [markdown]
# ### Classification Models

# %%
# !python src/fit_models.py --task classification --model logit

# %%
# !python src/fit_models.py --task classification --model rf

# %%
# !python src/fit_models.py --task classification --model xgb --use_gpu

# %%
# !python src/fit_models.py --task classification --model lstm --use_gpu

# %%
# !python src/fit_models.py --task classification --model transformer --use_gpu

# %% [markdown]
# ## Run Backtest

# %%
# !python src/backtest.py --task regression --model ridge
# !python src/backtest.py --task regression --model rf
# !python src/backtest.py --task regression --model xgb
# !python src/backtest.py --task regression --model lstm
# !python src/backtest.py --task regression --model transformer
# !python src/backtest.py --task classification --model logit
# !python src/backtest.py --task classification --model rf
# !python src/backtest.py --task classification --model xgb
# !python src/backtest.py --task classification --model lstm
# !python src/backtest.py --task classification --model transformer
